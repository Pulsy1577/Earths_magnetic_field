# %%
import physplot as phys
import numpy as np
from __future__ import division

array1 = np.array([-1.19,-.84,-.58,-.36,-.18,.18,.36,.58,.84,1.19])
array2 = np.array([-35.2,-25.8,-16.3,-10.49,-4.58,4.08,10.34,16.01,24.2,35.7])/1000
errarray2 = np.array([.2,.2,.2,.2,.2,.2,.2,.2,.2,.2])/1000


#plotfit takes in parameters in this order
#phys.plotfit(x,y,dy,title,'xlabel(units)','ylabel(units)','slope units')  Slope units will not render in LaTeX

phys.plotfit(array1,array2,errarray2,'N = 100 turns','tan(theta)','I(A)','I/tan(theta)')

array3 = np.array([-1.19,-.84,-.58,-.36,-.18,.18,.36,.58,.84,1.19])
array4 = np.array([-17.52,-13.11,-8.09,-5.2,-2.39,1.98,5.22,9.09,12.28,17.83])/1000
errarray3 = np.array([.2,.2,.2,.2,.2,.2,.2,.2,.2,.2])/1000


phys.plotfit(array3,array4,errarray3,'N = 200 turns','tan(theta)','I(A)','I/tan(theta)')
# Out:
# Slope =  0.029420327468417242   I/tan(theta)
# Error in slope =  8.736873833967852e-05   I/tan(theta)
# Goodness of fit =  132.44066795160467
# Slope =  0.01486513873516278   I/tan(theta)
# Error in slope =  8.736873833967852e-05   I/tan(theta)
# Goodness of fit =  39.66958860348841
